# %% [markdown]
# <a href="https://colab.research.google.com/github/blackwithwhitegreen/DBSCAN-Algo/blob/main/DBSCAN_demo_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
X = np.array([[1,2],[2,2],[2,3],[8,7],[8,8],[25,88]])

# %%
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
db = DBSCAN(eps=3,min_samples=2)

# %%
db.fit(X)
db.labels_
# Out:
# array([ 0,  0,  0,  1,  1, -1])

# %% [markdown]
# #Here same points are represents in same clusters as 0 and 1.
# #Noise represents as -1.

# %%
from sklearn.datasets import make_circles
from sklearn.cluster import DBSCAN

# %%
X, _ = make_circles(n_samples=500,factor=0.5,noise=0.03,random_state=4)

# %%
dbscan = DBSCAN(eps=0.1,min_samples=5)
clusters = dbscan.fit_predict(X)

# %%
plt.scatter(X[:,0],X[:,1],c=clusters,cmap='viridis',marker='o')
plt.title("DBSCAN clustering of Concentric Circles")
plt.xlabel("Featrue 0")
plt.ylabel("Featrue 1")
plt.show()
